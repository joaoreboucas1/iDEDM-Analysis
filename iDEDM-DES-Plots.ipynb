# %% [markdown]
# # Literature Reproductions

# %%
import getdist
import numpy as np
from getdist import plots
import matplotlib

# %%
# GENERAL PLOT OPTIONS
matplotlib.rcParams['mathtext.fontset'] = 'stix'
matplotlib.rcParams['font.family'] = 'STIXGeneral'
matplotlib.rcParams['mathtext.rm'] = 'Bitstream Vera Sans'
matplotlib.rcParams['mathtext.it'] = 'Bitstream Vera Sans:italic'
matplotlib.rcParams['mathtext.bf'] = 'Bitstream Vera Sans:bold'
matplotlib.rcParams['xtick.bottom'] = True
matplotlib.rcParams['xtick.top'] = False
matplotlib.rcParams['ytick.right'] = False
matplotlib.rcParams['axes.edgecolor'] = 'black'
matplotlib.rcParams['axes.linewidth'] = '1.0'
matplotlib.rcParams['axes.labelsize'] = 'large'
matplotlib.rcParams['axes.grid'] = True
matplotlib.rcParams['grid.linewidth'] = '0.0'
matplotlib.rcParams['grid.alpha'] = '0.18'
matplotlib.rcParams['grid.color'] = 'lightgray'
matplotlib.rcParams['legend.labelspacing'] = 0.77
matplotlib.rcParams['savefig.bbox'] = 'tight'
matplotlib.rcParams['savefig.format'] = 'pdf'
matplotlib.rcParams['font.size'] = 25

# %%
# Loading Chains
analysis_settings = {u'ignore_rows':0.5}
codes = list(range(1,7))
labels = [
    r'DES-Y3 3x2pt ($\xi = 0$)',
    r'DES-Y3 3x2pt ($\xi < 0$)',
    r'DES-Y3 3x2pt ($\xi > 0$)',
    r'DES-Y3 Cosmic Shear ($\xi = 0$)',
    r'DES-Y3 Cosmic Shear ($\xi < 0$)',
    r'DES-Y3 Cosmic Shear ($\xi > 0$)'
    
]
chains = {}
chain_labels = {}
for code, label in zip(codes, labels):
    chains[code] = getdist.loadMCSamples('./chains/DES/MCMC{:d}'.format(code), settings=analysis_settings)
    chain_labels[code] = label

# %%
for code, chain in chains.items():
    chain.addDerived(chain['sigma8'] * np.sqrt(chain['omegam']/0.3), name='S8', label='S_8')

# %% [markdown]
# ### DES 3x2pt

# %%
plot = plots.get_single_plotter(width_inch=10, ratio=1)
plot.settings.rc_sizes(axes_fontsize=27, lab_fontsize=29, legend_fontsize=24)
plot.triangle_plot([chains[2], chains[3], chains[1]],
    ['omegam', 'S8', 'xi_interaction'],
    filled=True,
    contour_colors=['tab:red', 'tab:green', 'tab:blue'],
    contour_lws=3,
    legend_labels=[chain_labels[2], chain_labels[3], chain_labels[1]],
    legend_loc='upper right',
    #param_limits={"xi_interaction":[-1, 1]}
)
plot.export('Figures/DESY3_3x2_Interacting.pdf')

# %%
plot = plots.get_single_plotter(width_inch=10)
plot.settings.rc_sizes(axes_fontsize=27, lab_fontsize=29, legend_fontsize=24)
plot.plot_3d(chains[2], ['omegam', 'S8', 'xi_interaction'], scatter_size=10)

# %% [markdown]
# ### ACT only, $\Lambda \mathrm{CDM}$ vs $\xi \Lambda \mathrm{CDM}$

# %%
plot = plots.get_single_plotter(width_inch=10, ratio=1)
plot.settings.rc_sizes(axes_fontsize=27, lab_fontsize=29, legend_fontsize=24)
plot.triangle_plot([chains[5], chains[6], chains[4]],
    ['omegam', 'S8', 'xi_interaction'],
    filled=True,
    contour_colors=['tab:red', 'tab:green', 'tab:blue'],
    contour_lws=3,
    legend_labels=[chain_labels[5], chain_labels[6], chain_labels[4]],
    legend_loc='upper right',
    #param_limits={"xi_interaction":[-1, 1]}
)
# plot.export('Figures/ACT_xiLCDM.pdf')

# %% [markdown]
# ### ACT + BAO + SNe, $\Lambda \mathrm{CDM}$ vs $\xi \Lambda \mathrm{CDM}$

# %%
plot = plots.get_single_plotter(width_inch=10, ratio=1)
plot.settings.rc_sizes(axes_fontsize=27, lab_fontsize=29, legend_fontsize=24)
plot.triangle_plot([chains[2], chains[5]],
                   ['omch2', 'xi_interaction', 'H0', 'omegam', 'S8'],
                   filled=True,
                   contour_colors=['tab:blue', 'orange'],
                   contour_lws=3,
                   legend_labels=[chain_labels[2], chain_labels[5]],
                   legend_loc='upper right')
plot.export('Figures/ACT_BAO_SNE_xiLCDM_vs_LCDM.pdf')

# %% [markdown]
# ## Plotting all ACT $\xi$ qCDM chains

# %%
plot = plots.get_single_plotter(width_inch=10, ratio=1)
plot.settings.rc_sizes(axes_fontsize=27, lab_fontsize=29, legend_fontsize=24)
plot.triangle_plot([chains[11], chains[12], chains[13]],
                   ['omch2', 'xi_interaction', 'H0', 'omegam', 'w'],
                   filled=True,
                   contour_colors=['tab:red', 'tab:green', 'tab:blue'],
                   contour_lws=3,
                   legend_labels=[chain_labels[11], chain_labels[12], chain_labels[13]],
                   legend_loc='upper right')
g.export('Figures/ACT_xiqCDM.pdf')
# Out:
# WARNING:root:2D kernel density bandwidth optimizer failed for omegach2, H0. Using fallback width: f(a) and f(b) must have different signs
# WARNING:root:2D kernel density bandwidth optimizer failed for omegach2, omegam. Using fallback width: f(a) and f(b) must have different signs
# WARNING:root:2D kernel density bandwidth optimizer failed for xi_interaction, omegam. Using fallback width: f(a) and f(b) must have different signs
# WARNING:root:2D kernel density bandwidth optimizer failed for H0, omegam. Using fallback width: f(a) and f(b) must have different signs

# %% [markdown]
# ### ACT + BAO + SNe, $\mathrm{qCDM}$ vs $\xi \mathrm{qCDM}$

# %%
plot = plots.get_single_plotter(width_inch=10, ratio=1)
plot.settings.rc_sizes(axes_fontsize=27, lab_fontsize=29, legend_fontsize=24)
plot.triangle_plot([chains[12], chains[15]],
                   ['omch2', 'xi_interaction', 'H0', 'omegam', 'S8', 'w'],
                   filled=True,
                   contour_colors=['tab:blue', 'orange'],
                   contour_lws=3,
                   legend_labels=[chain_labels[12], chain_labels[15]],
                   legend_loc='upper right')
plot.export('Figures/ACT_BAO_SNe_xiqCDM_vs_qCDM.pdf')

# %% [markdown]
# ## Plotting all ACT $\xi$ pCDM chains

# %%
plot = plots.get_single_plotter(width_inch=10, ratio=1)
plot.settings.rc_sizes(axes_fontsize=27, lab_fontsize=29, legend_fontsize=24)
plot.triangle_plot([chains[21], chains[22], chains[23]],
                   ['omch2', 'xi_interaction', 'H0', 'omegam', 'w'],
                   filled=True,
                   contour_colors=['tab:red', 'tab:green', 'tab:blue'],
                   contour_lws=3,
                   legend_labels=[chain_labels[21], chain_labels[22], chain_labels[23]],
                   legend_loc='upper right')
g.export('Figures/ACT_xipCDM.pdf')

# %% [markdown]
# ### ACT + BAO + SNe, $\mathrm{pCDM}$ vs $\xi \mathrm{pCDM}$

# %%
plot = plots.get_single_plotter(width_inch=10, ratio=1)
plot.settings.rc_sizes(axes_fontsize=27, lab_fontsize=29, legend_fontsize=24)
plot.triangle_plot([chains[22], chains[25]],
                   ['omch2', 'xi_interaction', 'H0', 'omegam', 'S8', 'w'],
                   filled=True,
                   contour_colors=['tab:blue', 'orange'],
                   contour_lws=3,
                   legend_labels=[chain_labels[22], chain_labels[25]],
                   legend_loc='upper right')
plot.export('Figures/ACT_BAO_SNe_xipCDM_vs_pCDM.pdf')

# %% [markdown]
# ### ACT + BAO + SNe + DES, $\mathrm{pCDM}$ vs $\xi \mathrm{pCDM}$

# %%
plot = plots.get_single_plotter(width_inch=10, ratio=1)
plot.settings.rc_sizes(axes_fontsize=27, lab_fontsize=29, legend_fontsize=24)
plot.triangle_plot([chains[52], chains[55]],
                   ['omch2', 'xi_interaction', 'H0', 'omegam', 'S8', 'w'],
                   filled=True,
                   contour_colors=['tab:blue', 'orange'],
                   contour_lws=3,
                   legend_labels=[chain_labels[52], chain_labels[55]],
                   legend_loc='upper right')
plot.export('Figures/ACT_BAO_SNe_DES_xipCDM_vs_pCDM.pdf')

# %% [markdown]
# ### ACT + BAO + SNe + DES, $\mathrm{qCDM}$ vs $\xi \mathrm{qCDM}$

# %%
plot = plots.get_single_plotter(width_inch=10, ratio=1)
plot.settings.rc_sizes(axes_fontsize=27, lab_fontsize=29, legend_fontsize=24)
plot.triangle_plot([chains[42], chains[45]],
                   ['omch2', 'xi_interaction', 'H0', 'omegam', 'S8', 'w'],
                   filled=True,
                   contour_colors=['tab:blue', 'orange'],
                   contour_lws=3,
                   legend_labels=[chain_labels[42], chain_labels[45]],
                   legend_loc='upper right')
plot.export('Figures/ACT_BAO_SNe_DES_xiqCDM_vs_qCDM.pdf')

# %% [markdown]
# ### ACT + BAO + SNe + DES, $\Lambda\mathrm{CDM}$ vs $\xi \Lambda \mathrm{CDM}$

# %%
plot = plots.get_single_plotter(width_inch=10, ratio=1)
plot.settings.rc_sizes(axes_fontsize=27, lab_fontsize=29, legend_fontsize=24)
plot.triangle_plot([chains[32], chains[35]],
                   ['omch2', 'xi_interaction', 'H0', 'omegam', 'S8'],
                   filled=True,
                   contour_colors=['tab:blue', 'orange'],
                   contour_lws=3,
                   legend_labels=[chain_labels[32], chain_labels[35]],
                   legend_loc='upper right')
plot.export('Figures/ACT_BAO_SNe_DES_xiLCDM_vs_LCDM.pdf')
